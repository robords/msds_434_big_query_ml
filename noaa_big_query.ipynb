# %%
from google.cloud import bigquery
# Construct a BigQuery client object.
client = bigquery.Client()
# Out:
# /Users/robords/.venv/big_query_ml/lib/python3.7/site-packages/google/auth/_default.py:81: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /Users/robords/.venv/big_query_ml/lib/python3.7/site-packages/google/auth/_default.py:81: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %% [markdown]
# ### Get the list of tables in the dataset

# %%
dataset_id = 'bigquery-public-data.ghcn_d'
tables = client.list_tables(dataset_id)  # Make an API request.

tables_in_noaa_dataset = []
for table in tables:
    tables_in_noaa_dataset.append("{}.{}.{}".format(table.project, table.dataset_id, table.table_id))

# %% [markdown]
# ### Get the schemas of each table in the dataset

# %%
tables_in_noaa_dataset[0:]
# Out:
# ['bigquery-public-data.ghcn_d.ghcnd_1763',
#  'bigquery-public-data.ghcn_d.ghcnd_1764',
#  'bigquery-public-data.ghcn_d.ghcnd_1765',
#  'bigquery-public-data.ghcn_d.ghcnd_1766',
#  'bigquery-public-data.ghcn_d.ghcnd_1767',
#  'bigquery-public-data.ghcn_d.ghcnd_1768',
#  'bigquery-public-data.ghcn_d.ghcnd_1769',
#  'bigquery-public-data.ghcn_d.ghcnd_1770',
#  'bigquery-public-data.ghcn_d.ghcnd_1771',
#  'bigquery-public-data.ghcn_d.ghcnd_1772',
#  'bigquery-public-data.ghcn_d.ghcnd_1773',
#  'bigquery-public-data.ghcn_d.ghcnd_1774',
#  'bigquery-public-data.ghcn_d.ghcnd_1775',
#  'bigquery-public-data.ghcn_d.ghcnd_1776',
#  'bigquery-public-data.ghcn_d.ghcnd_1777',
#  'bigquery-public-data.ghcn_d.ghcnd_1778',
#  'bigquery-public-data.ghcn_d.ghcnd_1779',
#  'bigquery-public-data.ghcn_d.ghcnd_1780',
#  'bigquery-public-data.ghcn_d.ghcnd_1781',
#  'bigquery-public-data.ghcn_d.ghcnd_1782',
#  'bigquery-public-data.ghcn_d.ghcnd_1783',
#  'bigquery-public-data.ghcn_d.ghcnd_1784',
#  'bigquery-public-data.ghcn_d.ghcnd_1785',
#  'bigquery-public-data.ghcn_d.ghcnd_1786',
#  'bigquery-public-data.ghcn_d.ghcnd_1787',
#  'bigquery-public-data.ghcn_d.ghcnd_1788',
#  'bigquery-public-data.ghcn_d.ghcnd_1789',
#  'bigquery-public-data.ghcn_d.ghcnd_1790',
#  'bigquery-public-data.ghcn_d.ghcnd_1791',
#  'bigquery-public-data.ghcn_d.ghcnd_1792',
#  'bigquery-public-data.ghcn_d.ghcnd_1793',
#  'bigquery-public-data.ghcn_d.ghcnd_1794',
#  'bigquery-public-data.ghcn_d.ghcnd_1795',
#  'bigquery-public-data.ghcn_d.ghcnd_1796',
#  'bigquery-public-data.ghcn_d.ghcnd_1797',
#  'bigquery-public-data.ghcn_d.ghcnd_1798',
#  'bigquery-public-data.ghcn_d.ghcnd_1799',
#  'bigquery-public-data.ghcn_d.ghcnd_1800',
#  'bigquery-public-data.ghcn_d.ghcnd_1801',
#  'bigquery-public-data.ghcn_d.ghcnd_1802',
#  'bigquery-public-data.ghcn_d.ghcnd_1803',
#  'bigquery-public-data.ghcn_d.ghcnd_1804',
#  'bigquery-public-data.ghcn_d.ghcnd_1805',
#  'bigquery-public-data.ghcn_d.ghcnd_1806',
#  'bigquery-public-data.ghcn_d.ghcnd_1807',
#  'bigquery-public-data.ghcn_d.ghcnd_1808',
#  'bigquery-public-data.ghcn_d.ghcnd_1809',
#  'bigquery-public-data.ghcn_d.ghcnd_1810',
#  'bigquery-public-data.ghcn_d.ghcnd_1811',
#  'bigquery-public-data.ghcn_d.ghcnd_1812',
#  'bigquery-public-data.ghcn_d.ghcnd_1813',
#  'bigquery-public-data.ghcn_d.ghcnd_1814',
#  'bigquery-public-data.ghcn_d.ghcnd_1815',
#  'bigquery-public-data.ghcn_d.ghcnd_1816',
#  'bigquery-public-data.ghcn_d.ghcnd_1817',
#  'bigquery-public-data.ghcn_d.ghcnd_1818',
#  'bigquery-public-data.ghcn_d.ghcnd_1819',
#  'bigquery-public-data.ghcn_d.ghcnd_1820',
#  'bigquery-public-data.ghcn_d.ghcnd_1821',
#  'bigquery-public-data.ghcn_d.ghcnd_1822',
#  'bigquery-public-data.ghcn_d.ghcnd_1823',
#  'bigquery-public-data.ghcn_d.ghcnd_1824',
#  'bigquery-public-data.ghcn_d.ghcnd_1825',
#  'bigquery-public-data.ghcn_d.ghcnd_1826',
#  'bigquery-public-data.ghcn_d.ghcnd_1827',
#  'bigquery-public-data.ghcn_d.ghcnd_1828',
#  'bigquery-public-data.ghcn_d.ghcnd_1829',
#  'bigquery-public-data.ghcn_d.ghcnd_1830',
#  'bigquery-public-data.ghcn_d.ghcnd_1831',
#  'bigquery-public-data.ghcn_d.ghcnd_1832',
#  'bigquery-public-data.ghcn_d.ghcnd_1833',
#  'bigquery-public-data.ghcn_d.ghcnd_1834',
#  'bigquery-public-data.ghcn_d.ghcnd_1835',
#  'bigquery-public-data.ghcn_d.ghcnd_1836',
#  'bigquery-public-data.ghcn_d.ghcnd_1837',
#  'bigquery-public-data.ghcn_d.ghcnd_1838',
#  'bigquery-public-data.ghcn_d.ghcnd_1839',
#  'bigquery-public-data.ghcn_d.ghcnd_1840',
#  'bigquery-public-data.ghcn_d.ghcnd_1841',
#  'bigquery-public-data.ghcn_d.ghcnd_1842',
#  'bigquery-public-data.ghcn_d.ghcnd_1843',
#  'bigquery-public-data.ghcn_d.ghcnd_1844',
#  'bigquery-public-data.ghcn_d.ghcnd_1845',
#  'bigquery-public-data.ghcn_d.ghcnd_1846',
#  'bigquery-public-data.ghcn_d.ghcnd_1847',
#  'bigquery-public-data.ghcn_d.ghcnd_1848',
#  'bigquery-public-data.ghcn_d.ghcnd_1849',
#  'bigquery-public-data.ghcn_d.ghcnd_1850',
#  'bigquery-public-data.ghcn_d.ghcnd_1851',
#  'bigquery-public-data.ghcn_d.ghcnd_1852',
#  'bigquery-public-data.ghcn_d.ghcnd_1853',
#  'bigquery-public-data.ghcn_d.ghcnd_1854',
#  'bigquery-public-data.ghcn_d.ghcnd_1855',
#  'bigquery-public-data.ghcn_d.ghcnd_1856',
#  'bigquery-public-data.ghcn_d.ghcnd_1857',
#  'bigquery-public-data.ghcn_d.ghcnd_1858',
#  'bigquery-public-data.ghcn_d.ghcnd_1859',
#  'bigquery-public-data.ghcn_d.ghcnd_1860',
#  'bigquery-public-data.ghcn_d.ghcnd_1861',
#  'bigquery-public-data.ghcn_d.ghcnd_1862',
#  'bigquery-public-data.ghcn_d.ghcnd_1863',
#  'bigquery-public-data.ghcn_d.ghcnd_1864',
#  'bigquery-public-data.ghcn_d.ghcnd_1865',
#  'bigquery-public-data.ghcn_d.ghcnd_1866',
#  'bigquery-public-data.ghcn_d.ghcnd_1867',
#  'bigquery-public-data.ghcn_d.ghcnd_1868',
#  'bigquery-public-data.ghcn_d.ghcnd_1869',
#  'bigquery-public-data.ghcn_d.ghcnd_1870',
#  'bigquery-public-data.ghcn_d.ghcnd_1871',
#  'bigquery-public-data.ghcn_d.ghcnd_1872',
#  'bigquery-public-data.ghcn_d.ghcnd_1873',
#  'bigquery-public-data.ghcn_d.ghcnd_1874',
#  'bigquery-public-data.ghcn_d.ghcnd_1875',
#  'bigquery-public-data.ghcn_d.ghcnd_1876',
#  'bigquery-public-data.ghcn_d.ghcnd_1877',
#  'bigquery-public-data.ghcn_d.ghcnd_1878',
#  'bigquery-public-data.ghcn_d.ghcnd_1879',
#  'bigquery-public-data.ghcn_d.ghcnd_1880',
#  'bigquery-public-data.ghcn_d.ghcnd_1881',
#  'bigquery-public-data.ghcn_d.ghcnd_1882',
#  'bigquery-public-data.ghcn_d.ghcnd_1883',
#  'bigquery-public-data.ghcn_d.ghcnd_1884',
#  'bigquery-public-data.ghcn_d.ghcnd_1885',
#  'bigquery-public-data.ghcn_d.ghcnd_1886',
#  'bigquery-public-data.ghcn_d.ghcnd_1887',
#  'bigquery-public-data.ghcn_d.ghcnd_1888',
#  'bigquery-public-data.ghcn_d.ghcnd_1889',
#  'bigquery-public-data.ghcn_d.ghcnd_1890',
#  'bigquery-public-data.ghcn_d.ghcnd_1891',
#  'bigquery-public-data.ghcn_d.ghcnd_1892',
#  'bigquery-public-data.ghcn_d.ghcnd_1893',
#  'bigquery-public-data.ghcn_d.ghcnd_1894',
#  'bigquery-public-data.ghcn_d.ghcnd_1895',
#  'bigquery-public-data.ghcn_d.ghcnd_1896',
#  'bigquery-public-data.ghcn_d.ghcnd_1897',
#  'bigquery-public-data.ghcn_d.ghcnd_1898',
#  'bigquery-public-data.ghcn_d.ghcnd_1899',
#  'bigquery-public-data.ghcn_d.ghcnd_1900',
#  'bigquery-public-data.ghcn_d.ghcnd_1901',
#  'bigquery-public-data.ghcn_d.ghcnd_1902',
#  'bigquery-public-data.ghcn_d.ghcnd_1903',
#  'bigquery-public-data.ghcn_d.ghcnd_1904',
#  'bigquery-public-data.ghcn_d.ghcnd_1905',
#  'bigquery-public-data.ghcn_d.ghcnd_1906',
#  'bigquery-public-data.ghcn_d.ghcnd_1907',
#  'bigquery-public-data.ghcn_d.ghcnd_1908',
#  'bigquery-public-data.ghcn_d.ghcnd_1909',
#  'bigquery-public-data.ghcn_d.ghcnd_1910',
#  'bigquery-public-data.ghcn_d.ghcnd_1911',
#  'bigquery-public-data.ghcn_d.ghcnd_1912',
#  'bigquery-public-data.ghcn_d.ghcnd_1913',
#  'bigquery-public-data.ghcn_d.ghcnd_1914',
#  'bigquery-public-data.ghcn_d.ghcnd_1915',
#  'bigquery-public-data.ghcn_d.ghcnd_1916',
#  'bigquery-public-data.ghcn_d.ghcnd_1917',
#  'bigquery-public-data.ghcn_d.ghcnd_1918',
#  'bigquery-public-data.ghcn_d.ghcnd_1919',
#  'bigquery-public-data.ghcn_d.ghcnd_1920',
#  'bigquery-public-data.ghcn_d.ghcnd_1921',
#  'bigquery-public-data.ghcn_d.ghcnd_1922',
#  'bigquery-public-data.ghcn_d.ghcnd_1923',
#  'bigquery-public-data.ghcn_d.ghcnd_1924',
#  'bigquery-public-data.ghcn_d.ghcnd_1925',
#  'bigquery-public-data.ghcn_d.ghcnd_1926',
#  'bigquery-public-data.ghcn_d.ghcnd_1927',
#  'bigquery-public-data.ghcn_d.ghcnd_1928',
#  'bigquery-public-data.ghcn_d.ghcnd_1929',
#  'bigquery-public-data.ghcn_d.ghcnd_1930',
#  'bigquery-public-data.ghcn_d.ghcnd_1931',
#  'bigquery-public-data.ghcn_d.ghcnd_1932',
#  'bigquery-public-data.ghcn_d.ghcnd_1933',
#  'bigquery-public-data.ghcn_d.ghcnd_1934',
#  'bigquery-public-data.ghcn_d.ghcnd_1935',
#  'bigquery-public-data.ghcn_d.ghcnd_1936',
#  'bigquery-public-data.ghcn_d.ghcnd_1937',
#  'bigquery-public-data.ghcn_d.ghcnd_1938',
#  'bigquery-public-data.ghcn_d.ghcnd_1939',
#  'bigquery-public-data.ghcn_d.ghcnd_1940',
#  'bigquery-public-data.ghcn_d.ghcnd_1941',
#  'bigquery-public-data.ghcn_d.ghcnd_1942',
#  'bigquery-public-data.ghcn_d.ghcnd_1943',
#  'bigquery-public-data.ghcn_d.ghcnd_1944',
#  'bigquery-public-data.ghcn_d.ghcnd_1945',
#  'bigquery-public-data.ghcn_d.ghcnd_1946',
#  'bigquery-public-data.ghcn_d.ghcnd_1947',
#  'bigquery-public-data.ghcn_d.ghcnd_1948',
#  'bigquery-public-data.ghcn_d.ghcnd_1949',
#  'bigquery-public-data.ghcn_d.ghcnd_1950',
#  'bigquery-public-data.ghcn_d.ghcnd_1951',
#  'bigquery-public-data.ghcn_d.ghcnd_1952',
#  'bigquery-public-data.ghcn_d.ghcnd_1953',
#  'bigquery-public-data.ghcn_d.ghcnd_1954',
#  'bigquery-public-data.ghcn_d.ghcnd_1955',
#  'bigquery-public-data.ghcn_d.ghcnd_1956',
#  'bigquery-public-data.ghcn_d.ghcnd_1957',
#  'bigquery-public-data.ghcn_d.ghcnd_1958',
#  'bigquery-public-data.ghcn_d.ghcnd_1959',
#  'bigquery-public-data.ghcn_d.ghcnd_1960',
#  'bigquery-public-data.ghcn_d.ghcnd_1961',
#  'bigquery-public-data.ghcn_d.ghcnd_1962',
#  'bigquery-public-data.ghcn_d.ghcnd_1963',
#  'bigquery-public-data.ghcn_d.ghcnd_1964',
#  'bigquery-public-data.ghcn_d.ghcnd_1965',
#  'bigquery-public-data.ghcn_d.ghcnd_1966',
#  'bigquery-public-data.ghcn_d.ghcnd_1967',
#  'bigquery-public-data.ghcn_d.ghcnd_1968',
#  'bigquery-public-data.ghcn_d.ghcnd_1969',
#  'bigquery-public-data.ghcn_d.ghcnd_1970',
#  'bigquery-public-data.ghcn_d.ghcnd_1971',
#  'bigquery-public-data.ghcn_d.ghcnd_1972',
#  'bigquery-public-data.ghcn_d.ghcnd_1973',
#  'bigquery-public-data.ghcn_d.ghcnd_1974',
#  'bigquery-public-data.ghcn_d.ghcnd_1975',
#  'bigquery-public-data.ghcn_d.ghcnd_1976',
#  'bigquery-public-data.ghcn_d.ghcnd_1977',
#  'bigquery-public-data.ghcn_d.ghcnd_1978',
#  'bigquery-public-data.ghcn_d.ghcnd_1979',
#  'bigquery-public-data.ghcn_d.ghcnd_1980',
#  'bigquery-public-data.ghcn_d.ghcnd_1981',
#  'bigquery-public-data.ghcn_d.ghcnd_1982',
#  'bigquery-public-data.ghcn_d.ghcnd_1983',
#  'bigquery-public-data.ghcn_d.ghcnd_1984',
#  'bigquery-public-data.ghcn_d.ghcnd_1985',
#  'bigquery-public-data.ghcn_d.ghcnd_1986',
#  'bigquery-public-data.ghcn_d.ghcnd_1987',
#  'bigquery-public-data.ghcn_d.ghcnd_1988',
#  'bigquery-public-data.ghcn_d.ghcnd_1989',
#  'bigquery-public-data.ghcn_d.ghcnd_1990',
#  'bigquery-public-data.ghcn_d.ghcnd_1991',
#  'bigquery-public-data.ghcn_d.ghcnd_1992',
#  'bigquery-public-data.ghcn_d.ghcnd_1993',
#  'bigquery-public-data.ghcn_d.ghcnd_1994',
#  'bigquery-public-data.ghcn_d.ghcnd_1995',
#  'bigquery-public-data.ghcn_d.ghcnd_1996',
#  'bigquery-public-data.ghcn_d.ghcnd_1997',
#  'bigquery-public-data.ghcn_d.ghcnd_1998',
#  'bigquery-public-data.ghcn_d.ghcnd_1999',
#  'bigquery-public-data.ghcn_d.ghcnd_2000',
#  'bigquery-public-data.ghcn_d.ghcnd_2001',
#  'bigquery-public-data.ghcn_d.ghcnd_2002',
#  'bigquery-public-data.ghcn_d.ghcnd_2003',
#  'bigquery-public-data.ghcn_d.ghcnd_2004',
#  'bigquery-public-data.ghcn_d.ghcnd_2005',
#  'bigquery-public-data.ghcn_d.ghcnd_2006',
#  'bigquery-public-data.ghcn_d.ghcnd_2007',
#  'bigquery-public-data.ghcn_d.ghcnd_2008',
#  'bigquery-public-data.ghcn_d.ghcnd_2009',
#  'bigquery-public-data.ghcn_d.ghcnd_2010',
#  'bigquery-public-data.ghcn_d.ghcnd_2011',
#  'bigquery-public-data.ghcn_d.ghcnd_2012',
#  'bigquery-public-data.ghcn_d.ghcnd_2013',
#  'bigquery-public-data.ghcn_d.ghcnd_2014',
#  'bigquery-public-data.ghcn_d.ghcnd_2015',
#  'bigquery-public-data.ghcn_d.ghcnd_2016',
#  'bigquery-public-data.ghcn_d.ghcnd_2017',
#  'bigquery-public-data.ghcn_d.ghcnd_2018',
#  'bigquery-public-data.ghcn_d.ghcnd_2019',
#  'bigquery-public-data.ghcn_d.ghcnd_2020',
#  'bigquery-public-data.ghcn_d.ghcnd_2021',
#  'bigquery-public-data.ghcn_d.ghcnd_2022',
#  'bigquery-public-data.ghcn_d.ghcnd_countries',
#  'bigquery-public-data.ghcn_d.ghcnd_inventory',
#  'bigquery-public-data.ghcn_d.ghcnd_states',
#  'bigquery-public-data.ghcn_d.ghcnd_stations']

# %%
table_id = 'bigquery-public-data.ghcn_d.ghcnd_2021'
table = client.get_table(table_id)  # Make an API request.

# View table properties
print(
    "Got table '{}.{}.{}'.".format(table.project, table.dataset_id, table.table_id)
)
print("Table schema: {}".format(table.schema))
print("Table description: {}".format(table.description))
print("Table has {} rows".format(table.num_rows))
# Out:
# Got table 'bigquery-public-data.ghcn_d.ghcnd_2021'.
# Table schema: [SchemaField('id', 'STRING', 'REQUIRED', '', (), None), SchemaField('date', 'DATE', 'NULLABLE', '', (), None), SchemaField('element', 'STRING', 'NULLABLE', '', (), None), SchemaField('value', 'FLOAT', 'NULLABLE', '', (), None), SchemaField('mflag', 'STRING', 'NULLABLE', '', (), None), SchemaField('qflag', 'STRING', 'NULLABLE', '', (), None), SchemaField('sflag', 'STRING', 'NULLABLE', '', (), None), SchemaField('time', 'STRING', 'NULLABLE', '', (), None), SchemaField('source_url', 'STRING', 'NULLABLE', 'Source ', (), None), SchemaField('etl_timestamp', 'TIMESTAMP', 'NULLABLE', 'Load time for this data row', (), None)]
# Table description: None
# Table has 37098011 rows

# %%
for table in tables_in_noaa_dataset:
    schema = []
    query = f"""
    SELECT
        * EXCEPT(is_generated, generation_expression, is_stored, is_updatable)
      FROM
        `bigquery-public-data`.census_bureau_usa.INFORMATION_SCHEMA.COLUMNS
      WHERE
        table_name = table;
    """
    query_job = client.query(query)  # Make an API request.

    query_job.to_dataframe()

# %%
_2021_data = """
SELECT
  *
FROM
  `bigquery-public-data.ghcn_d.ghcnd_2021`
LIMIT 10
"""
_2021_data_query_job = client.query(_2021_data)  # Make an API request.

_2021_data_query_job.to_dataframe()
# Out:
#             id        date element  value mflag qflag sflag  time  \
# 0  USC00084394  2021-10-23    TMAX  294.0  None  None     H  0800
# 1  USW00054795  2021-10-24    PRCP    0.0  None  None     R  None
# 2  USW00063869  2021-10-24    TMAX  238.0  None  None     R  None
# 3  USC00130046  2021-10-25    PRCP  406.0  None  None     H  None
# 4  USW00054903  2021-10-25    PRCP    0.0  None  None     R  None
# 5  USW00023803  2021-10-23    TMAX  247.0  None  None     R  None
# 6  CAW00064757  2021-10-24    PRCP    0.0  None  None     R  None
# 7  USC00227276  2021-10-24    TMIN  111.0  None  None     H  0730
# 8  USC00329233  2021-10-24    TMIN   17.0  None  None     H  0800
# 9  USW00094078  2021-10-24    PRCP    0.0  None  None     R  None
#
#                                           source_url  \
# 0  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 1  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 2  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 3  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 4  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 5  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 6  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 7  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 8  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
# 9  ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/by...
#
#                      etl_timestamp
# 0 2022-10-09 03:24:20.113166+00:00
# 1 2022-10-09 03:24:20.113166+00:00
# 2 2022-10-09 03:24:20.113166+00:00
# 3 2022-10-09 03:24:20.113166+00:00
# 4 2022-10-09 03:24:20.113166+00:00
# 5 2022-10-09 03:24:20.113166+00:00
# 6 2022-10-09 03:24:20.113166+00:00
# 7 2022-10-09 03:24:20.113166+00:00
# 8 2022-10-09 03:24:20.113166+00:00
# 9 2022-10-09 03:24:20.113166+00:00

# %%
query = """
SELECT
  id,
  name,
  state,
  latitude,
  longitude
FROM
  `bigquery-public-data.ghcn_d.ghcnd_stations`
WHERE
  latitude > 41.7
  AND latitude < 42
  AND longitude > -87.7
  AND longitude < -87.5
"""
query_job = client.query(query)  # Make an API request.

query_job.to_dataframe()
# Out:
# /Users/robords/.venv/cloud_weather_predictions/lib/python3.7/site-packages/google/auth/_default.py:81: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# /Users/robords/.venv/cloud_weather_predictions/lib/python3.7/site-packages/google/auth/_default.py:81: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. We recommend you rerun `gcloud auth application-default login` and make sure a quota project is added. Or you can use service accounts instead. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
#              id                      name state  latitude  longitude
# 0   USC00111562      CHICAGO SAN DIST OFC    IL   41.9000   -87.6333
# 1   US1ILCK0117            CHICAGO 3.0 NW    IL   41.9125   -87.6695
# 2   US1ILCK0108             BEVERLY 0.3 N    IL   41.7165   -87.6710
# 3   US1ILCK0104        LINCOLNWOOD 5.1 SE    IL   41.9494   -87.6703
# 4   US1ILCK0151     EVERGREEN PARK 0.5 NE    IL   41.7274   -87.6949
# 5   US1ILCK0122           CHICAGO 6.5 NNE    IL   41.9272   -87.6517
# 6   USC00111557       CHICAGO RACINE PUMP    IL   41.8167   -87.6500
# 7   US1ILCK0097           CHICAGO 6.8 NNE    IL   41.9301   -87.6393
# 8   USC00111584         CHICAGO WB CITY 2    IL   41.8833   -87.6333
# 9   US1ILCK0010             CHICAGO 3.0 N    IL   41.8798   -87.6823
# 10  USW00014892              CHICAGO UNIV    IL   41.7833   -87.6000
# 11  USC00111532     CHICAGO LAKEVIEW PUMP    IL   41.9667   -87.6667
# 12  US1ILCK0204  BOOT CAMP-CHICAGO 4.2 SW    IL   41.8421   -87.6891
# 13  US1ILCK0036            CHICAGO 4.7 NE    IL   41.8860   -87.6210
# 14  USC00111550      CHICAGO NORTHERLY IS    IL   41.8558   -87.6094
# 15  US1ILCK0168  RAVENSWOOD MANOR 0.1 ESE    IL   41.9642   -87.6974
# 16  US1ILCK0359           CHICAGO 5.5 NNW    IL   41.9502   -87.6815
# 17  US1ILCK0032           CHICAGO 6.4 NNE    IL   41.9266   -87.6562
# 18  USC00111564    CHICAGO S WTR FILT PLT    IL   41.7500   -87.5500
# 19  US1ILCK0214        ROGERS PARK 1.5 SW    IL   41.9957   -87.6918
# 20  US1ILCK0055           CHICAGO 6.0 NNE    IL   41.9170   -87.6386
# 21  US1ILCK0014           CHICAGO 5.5 ESE    IL   41.8008   -87.5903
# 22  US1ILCK0179           CHICAGO 4.8 NNW    IL   41.9481   -87.6588
# 23  US1ILCK0240           CHICAGO 2.7 WNW    IL   41.9018   -87.6726
# 24  USC00111526        CHICAGO GRANT PARK    IL   41.8833   -87.6167
# 25  USW00014881             FORT DEARBORN    IL   41.8883   -87.6258
